# %%
class Node:
    def __init__(self,data):
        self.data=data
class CList:
    def __init__(self):
        self.start=None
    def createlist(self):
        n=int(input("Enter number of nodes in the list:"))
        for i in range(n):
            data=int(input("Enter value:"))
            newnode=Node(data)
            if self.start==None:
                self.start=newnode
                newnode.next=newnode
            else:
                temp=self.start
                while temp.next!=self.start:
                    temp=temp.next
                temp.next=newnode
                newnode.next=self.start
    def insertbegin(self):
        data=int(input("Enter value"))
        newnode=Node(data)
        if self.start==None:
            self.start=newnode
            newnode.next=newnode
        else:
            temp=self.start
            while temp.next!=self.start:
                temp=temp.next
            temp.next=newnode
            newnode.next=self.start
            self.start=newnode
    def insertend(self):
        data=int(input("Enter value"))
        newnode=Node(data)
        if self.start==None:
            self.start=newnode
            newnode.next=newnode
        else:
            temp=self.start
            while temp.next!=self.start:
                temp=temp.next
            temp.next=newnode
            newnode.next=self.start
    def insertmid(self):
        print("Enter data before which number is to be inserted:")
        a=int(input())
        temp=self.start
        if self.start==None:
            print("List is empty")
        elif a==temp.data:
            self.insertbegin()
        else:
            ptemp=self.start
            temp=ptemp.next
            while temp.next!=self.start and temp.data!=a:
                ptemp=temp
                temp=temp.next
            if temp==self.start:
                print(a,"Data does not exist")
            else:
                print("Enter element to insert")
                x=int(input())
                newnode=Node(x)
                ptemp.next=newnode
                newnode.next=temp
                print(x,"is inserted success")
    def deletebegin(self):
        temp=self.start
        if self.start==None:
            print("List is empty, deletion not possible")
        elif temp.next==temp:
            print(temp.data,"is deleted success")
            del temp
            self.start==None
        else:
            dtemp=self.start
            while temp.next!=self.start:
                temp=temp.next
            temp.next=dtemp.next
            self.start=dtemp.next
            print(dtemp.data,"is deleted success")
            del temp
    def deleteend(self):
        temp=self.start
        if self.start==None:
            print("List is empty, deletion not possible")
        elif temp.next==temp:
            print(temp.data,"is deleted success")
            del temp
            self.start=None
        else:
            ptemp=temp
            temp=temp.next
            while temp.next!=self.start:
                ptemp=temp
                temp=temp.next
            ptemp.next=self.start
            print(temp.data,"is deleted success")
            del temp
    def deletion(self):
        print("Enter element to delete")
        a=int(input())
        temp=self.start
        if self.start==None:
            print("List is empty, deletion not possible")
            return
        elif temp.next==temp:
            if a==temp.data:
                print(temp.data,"is deleted success")
                self.start=None
                del temp
            else:
                print("Element not found")
        elif a==temp.data:
            self.deletebegin()
        else:
            ptemp=self.start
            temp=ptemp.next
            while temp.next!=self.start and temp.data!=a:
                ptemp=temp
                temp=temp.next
            if temp.next==self.start:
                print(a,"Element not found")
            else:
                ptemp.next=temp.next
                print(temp.data,"is deleted success")
                del temp
    def display(self):
        if self.start==None:
            print("Linked list is empty")
        else:
            print("Elements in single linked list are:")
            temp=self.start
            print(temp.data,end=" ")
            while temp.next!=self.start:
                temp=temp.next
                print(temp.data,end=" ")
list1=CList()
ch=1
while ch!=9:
    print("\nEnter choice\n1.insertbegin 2.insertmid 3.insertend 4.creatinglist")
    print("5.deletebegin 6.deleteend 7.delete specific 8.display 9.quit")
    ch=int(input())
    if ch==1:
        list1.insertbegin()
    elif ch==2:
        list1.insertmid()
    elif ch==3:
        list1.insertend()
    elif ch==4:
        list1.createlist()
    elif ch==5:
        list1.deletebegin()
    elif ch==6:
        list1.deleteend()
    elif ch==7:
        list1.deletion()
    elif ch==8:
        list1.display()
    else:
        print("End of the program")
# Out:
# Enter choice
# 1.insertbegin 2.insertmid 3.insertend 4.creatinglist
# 5.deletebegin 6.deleteend 7.delete specific 8.display 9.quit
# 1
# Enter value12
#
# Enter choice
# 1.insertbegin 2.insertmid 3.insertend 4.creatinglist
# 5.deletebegin 6.deleteend 7.delete specific 8.display 9.quit
# 8
# Elements in single linked list are:
# 12
# Enter choice
# 1.insertbegin 2.insertmid 3.insertend 4.creatinglist
# 5.deletebegin 6.deleteend 7.delete specific 8.display 9.quit
# 0
# End of the program
#
# Enter choice
# 1.insertbegin 2.insertmid 3.insertend 4.creatinglist
# 5.deletebegin 6.deleteend 7.delete specific 8.display 9.quit
# 9
# End of the program
