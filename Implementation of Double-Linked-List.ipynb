# %%
#Double Linked list
class node:
    def __init__(self,data):
        self.data = data
        self.prev = None
        self.next = None
class DList():
    def __init__(self):
        self.head = None
    def insertbegin(self):
        n=int(input())
        newnode=node(n)
        if(self.head==None):
            self.head=newnode
        else:
            temp=self.head
            self.head=newnode
            self.head.next=temp
            temp.prev=self
    def insertend(self):
        n=int(input())
        newnode=node(n)
        if(self.head==None):
            self.head=newnode
        else:
            temp=self.head
            while(temp.next!=None):
                temp=temp.next
            temp.next=newnode
            newnode.prev=temp
    def insertmid(self):
        n=int(input())
        newnode=node(n)
        p=int(input())
        temp=self.head
        previous=temp
        for i in range(p-1):
            previous=temp
            temp=temp.next
        previous.next=newnode
        newnode.next=temp
        temp.prev=newnode
        newnode.prev=previous
    def deletebegin(self):
        temp=self.head
        self.head=temp.next
        del temp
    def deleteend(self):
        temp=self.head
        previous=temp
        while(temp.next!=None):
            previous=temp
            temp=temp.next
        previous.next=None
        del temp
    def deletemid(self):
        q=int(input())
        temp=self.head
        previous=self
        for i in range(q-1):
            previous=temp
            temp=temp.next
        previous.next=temp.next
        temp.next.prev=previous
        del temp
    def display(self):
        temp=self.head
        while(temp!=None):
            print(temp.data,end=' ')
            temp=temp.next
        print()
    def reverse(self):
        temp=self.head
        while(temp.next!=None):
            temp=temp.next
        while(temp!=None):
            print(temp.data,end=' ')
            temp=temp.prev
        print()
# Driver code
list1 = DList()
ch = 1
while ch != 9:
    print("\n enter choice \n1-insertbegin 2-insertmid 3-insertend 4-creating list")
    print("5-deletebegin 6-deletend 7-delete specific 8-display 9-reverse 10-quit")
    ch = int(input())
    if ch == 1:
        list1.insertbegin()
    elif ch == 2:
        list1.insertmid()
    elif ch == 3:
        list1.insertend()
    elif ch == 4:
        list1.createlist()
    elif ch == 5:
        list1.deletebegin()
    elif ch == 6:
        list1.deletend()
    elif ch == 7:
        list1.deletion()
    elif ch == 8:
        list1.display()
    elif ch == 9:
        list1.reverse()
    else :
        print("end of the program")
# Out:
#  enter choice
# 1-insertbegin 2-insertmid 3-insertend 4-creating list
# 5-deletebegin 6-deletend 7-delete specific 8-display 9-reverse 10-quit
# 1
# 20
#
#  enter choice
# 1-insertbegin 2-insertmid 3-insertend 4-creating list
# 5-deletebegin 6-deletend 7-delete specific 8-display 9-reverse 10-quit
# 3
# 30
#
#  enter choice
# 1-insertbegin 2-insertmid 3-insertend 4-creating list
# 5-deletebegin 6-deletend 7-delete specific 8-display 9-reverse 10-quit
# 8
# 20 30
#
#  enter choice
# 1-insertbegin 2-insertmid 3-insertend 4-creating list
# 5-deletebegin 6-deletend 7-delete specific 8-display 9-reverse 10-quit
# 9
# 30 20
