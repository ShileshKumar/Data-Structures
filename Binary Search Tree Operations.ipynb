# %%
class BSTNode:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
class BST:
    def __init__(self):
        self.root=None
        self.count=0
    def insert(self,data):
        temp=self.root
        if temp is None:
            self.root=BSTNode(data)
        else:
            while 1:
                if data<temp.data:
                    if temp.left:
                        temp=temp.left
                    else:
                        temp.left=BSTNode(data)
                elif(data>temp.data):
                    if temp.right:
                        temp=temp.right
                    else:
                        temp.right=BSTNode(data)
                else:
                    break
    def inorder(self,node):
        if node is not None:
            self.inorder(node.left)
            print(node.data,end=" ")
            self.inorder(node.right)
    def preorder(self,node):
        if node is not None:
            print(node.data,end=" ")
            self.preorder(node.left)
            self.preorder(node.right)
    def postorder(self,node):
        if node is not None:
            self.postorder(node.left)
            self.postorder(node.right)
            print(node.data,end=" ")
    def nodecount(self,node):
        if node is not None:
            t.count=t.count+1
            self.nodecount(node.left)
            self.nodecount(node.right)

        return t.count
#driver
t=BST()
ch=1
while ch!=6:
    print("\nBinary Search Tree Operations:")
    print("1.Creation of BST 2.Traverse in Inorder 3.Traverse in Preorder")
    print("4.Traverse in Postorder 5.Count 6. Exit")
    print("Enter your choice:")
    ch=int(input())
    if ch==1:
        while 1:
            print("Enter element to be inserted and -1 to stop")
            elt=int(input())
            if elt==-1:
                break
            else:
                t.insert(elt)
    elif ch==2:
        print("BST Traversal in INORDER")
        t.inorder(t.root)
    elif ch==3:
        print("BST Traversal in PREORDER")
        t.preorder(t.root)
    elif ch==4:
        print("BST Traversal in POSTORDER")
        t.postorder(t.root)
    elif ch==5:
        n=t.nodecount(t.root)
        print("Total nodes:",n)
    else:
        print("End of program")
# Out:
# Binary Search Tree Operations:
# 1.Creation of BST 2.Traverse in Inorder 3.Traverse in Preorder
# 4.Traverse in Postorder 5.Count 6. Exit
# Enter your choice:
# 6
# End of program
