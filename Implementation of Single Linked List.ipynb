# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
class Slist:
    def __init__(self):
        self.head=None
    def createlist(self):
        n=int(input("Enter number of nodes in the list:"))
        for i in range(n):
            data=int(input("Enter value:"))
            newnode=Node(data)
            if self.head==None:
                self.head=newnode
            else:
                temp=self.head
                while temp.next!=None:
                    temp=temp.next
                temp.next=newnode
    def insertbegin(self):
        data=int(input("enter value"))
        newnode=Node(data)
        if self.head==None:
            self.head=newnode
        else:
            newnode.next=self.head
            self.head=newnode
    def insertend(self):
        data=int(input("enter value"))
        newnode=Node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while temp.next!=None:
                temp=temp.next
            temp.next=newnode
    def insertmid(self):
        print("enter data before which number is to be inserted:")
        a=int(input())
        temp=self.head
        if self.head==None:
            print("List is empty")
        elif a==temp.data:
            self.insertbegin()
        else:
            ptemp=self.head
            temp=ptemp.next
            while temp.next!=None and temp.data!=a:
                ptemp=temp
                temp=temp.next
            if temp==None:
                print(x,"Data does not exist")
            else:
                print("enter element to insert")
                x=int(input())
                newnode=Node(x)
                ptemp.next=newnode
                newnode.next=temp
                print(x,"is inserted success")
    def deletebegin(self):
        if self.head==None:
            print("List is empty, deletion not possible")
        else:
            temp=self.head
            self.head=temp.next
            print(temp.data,"is deleted success")
            del temp
    def deleteend(self):
        temp=self.head
        if self.head==None:
            print("List is empty, deletion not possible")
        elif temp.next==None:
            self.head=None
        else:
            ptemp=temp
            temp=temp.next
            while temp.next!=None:
                ptemp=temp
                temp=temp.next
            ptemp.next=None
            print(temp.data,"is deleted success")
            del temp
    def deletion(self):
        print("enter element to delete")
        a=int(input())
        temp=self.head
        if self.head==None:
            print("List is empty, deletion not possible")
            return
        elif a==temp.data:
            self.head=temp.next
            print(temp.data,"is deleted success")
            del temp
        else:
            ptemp=self.head
            temp=ptemp.next
            while temp.next!=None and temp.data!=a:
                ptemp=temp
                temp=temp.next
                if temp.next==None:
                    print(a,"Element not found")
                else:
                    ptemp.next=temp.next
                    print(temp.data,"is deleted success")
                    del temp
    def deletenode(self):
        n=int(input("enter node number to be deleted"))
        if self.head==None:
            print("List is empty")
        elif n==1:
            self.deletebegin()
        else:
            ptemp=self.head
            temp=ptemp.next
            for i in range(2,n):
                ptemp=temp
                temp=temp.next
            ptemp.next=temp.next
            print(temp.data,"is deleted success")
            del temp
    def display(self):
        print("elements in single linked list are:")
        if self.head==None:
            print("Linked list is empty")
        else:
            temp=self.head
            while temp!=None:
                print(temp.data,end=" ")
                temp=temp.next
list1=Slist()
ch=1
while ch!=10:
    print("enter choice\n1.insertbegin 2.insertmid 3.insertmid 4.createlist")
    print("5.deletebegin 6.deleteend 7.deletespecific 8. delete nth node")
    print("9.display 10.quit")
    ch=int(input())
    if ch==1:
        list1.insertbegin()
    elif ch==2:
        list1.insertmid()
    elif ch==3:
        list1.insertend()
    elif ch==4:
        list1.createlist()
    elif ch==5:
        list1.deletebegin()
    elif ch==6:
        list1.deleteend()
    elif ch==7:
        list1.deletion()
    elif ch==8:
        lit1.deletenode()
    elif ch==9:
        list1.display()
    else:
        print("end of the program")
# Out:
# enter choice
# 1.insertbegin 2.insertmid 3.insertmid 4.createlist
# 5.deletebegin 6.deleteend 7.deletespecific 8. delete nth node
# 9.display 10.quit
# 10
# end of the program
